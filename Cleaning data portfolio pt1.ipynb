# %%
# Importing the necessary libraries to organize the data into a meaningful story through 
#the combination of statistical, visual, and narrative story telling tools.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sy
from scipy.stats.stats import pearsonr
# %matplotlib inline

# %% [markdown]
# #Standard Workflow for cleaning data excercise
#
# Import data
#
# Join multiple data sets
#
# Detect missing values
#
# Look for anomalies (1, 2, 3, “Fred”?)
#
# Impute for missing values
#
# Data quality assurance
#
# reference https://www.dataoptimal.com/data-science-projects-2018/

# %%
#ccdata is the concatonation of consumer complaint data from the following website 
#https://catalog.data.gov/dataset/consumer-complaint-database#topic=consumer_navigation
ccdata= pd.read_csv("complaints.csv")

# %%
#size of the dataset
len('complaints')
# Out:
# 10

# %%
len(ccdata)
# Out:
# 1471179

# %%
ccdata.head()
# Out:
#   Date received                                            Product  \
# 0    08/09/2015                                   Credit reporting
# 1    12/23/2019                                       Student loan
# 2    01/29/2019  Credit reporting, credit repair services, or o...
# 3    08/19/2015                                           Mortgage
# 4    03/04/2016                                        Credit card
#
#                               Sub-product  \
# 0                                     NaN
# 1          Federal student loan servicing
# 2                        Credit reporting
# 3  Conventional adjustable mortgage (ARM)
# 4                                     NaN
#
#                                                Issue  \
# 0             Incorrect information on credit report
# 1               Dealing with your lender or servicer
# 2  Problem with a credit reporting company's inve...
# 3           Loan servicing, payments, escrow account
# ...

# %% [markdown]
# # Detecting missing values
# We actually don't need to drop any of the NaN's because it's not numerical

# %%
#Removed all columns and rows containing NAN values. 
#I just want to make it easier to be open to everything before delving deeper into the data
ccdata.dropna()
# Out:
#         Date received          Product                            Sub-product  \
# 253        10/10/2016  Debt collection                            Credit card
# 870        03/20/2015  Debt collection                          I do not know
# 1613       06/17/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 3703       11/22/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 5220       12/18/2015  Debt collection                            Credit card
# ...               ...              ...                                    ...
# 1467422    08/30/2016  Debt collection                          I do not know
# 1469823    10/31/2016  Debt collection                                Medical
# 1469867    12/04/2016     Student loan         Federal student loan servicing
# 1470504    05/17/2016  Debt collection                                   Auto
# 1470542    06/24/2015  Debt collection                          I do not know
#
# ...

# %%
len(ccdata)
# Out:
# 1471179

# %% [markdown]
# # Detecting outliers

# %% [markdown]
# I'm pretty sure I can't detect any outliers because I don't have any numerical data to deal with

# %% [markdown]
# # Exploretory Analysis

# %% [markdown]
# Who what when where why how

# %% [markdown]
# # Initial claning complete now on to the dataset specific rinse cycle

# %% [markdown]
# Set up the environment and load the data
#
# Investigate the data
#
# Parse the different data tabs
#
# Standardize existing columns and create new ones
#
# Clean up the data using “apply” and “lambda” functions
#
# Reshape the data from wide to long by pivoting on multi-level indices and stacking
#
# Concatenate and save the final results back to Excel
